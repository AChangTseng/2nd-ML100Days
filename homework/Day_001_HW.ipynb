# %% [markdown]
# # 作業1：
# 1. 選取資料集：Business and Industry Reports
#    與目前工作密切相關，需要了解國內外產業動態資訊。透過此活動可順便學習工作上可能會碰到的議題。
#
# 2. 美國人口普查局
#
# 3. CSV檔
#
# 4. 美國與台灣的產業動態是密切相關的，從此資料集中可能可取得目前美國產業的一些資訊及趨勢，
#    分析美國產業未來的發展走向，作為台灣經濟的發展參考。

# %% [markdown]
# ## 作業2:
# 1. 可使用平衡計分卡的概念定義各面向ＫＰＩ指標，作為提升業績量化的依據。
#    例如可分為財務面指標(銷售額)、客戶面指標(滿意度調查、投訴狀況、搭乘起迄時間、客戶基本資料)、
#    硬體面指標(收集車的GPS軌跡、平均時速、預定路徑)及輔助面指標(天氣狀況、降雨機率)等。
#    依據上述指標做分析後，希望能介定出較具有潛力的客源或時間，決策者再依結果制定對應的優化方案或調配車班提升績效最大化。
#
# 2. a.需在車上裝上各種不同感測器及小型電腦主機（例如GPS定位器、軌跡記錄器），並透過網路或回至總部方式上傳資料。
#    b.建立一套客服溝通機制，除了開放傳統電話客服外，也建置網站提供客戶填寫滿意度問卷。
#    c.建立OpenData爬蟲機制，定期收集與議題相關的資料(例如中央氣象局的天氣)
#    d.以上資料全部轉換並進入資料庫儲存。
#
# 3. 空間幾何資料(Gps點位、軌跡線)、表單資料(客戶問卷)及爬蟲網頁檔案
#
# 4. 以營業額作為驗證依據，當發現制定的策略不如預期營業額時，則需重新分析並制定新的策略。

# %% [markdown]
# ## 作業3
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    return sum((y - yp)**2) / len(y)

# %%
def mean_absolute_error(y, yp):
    mae = sum(abs(y - yp)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
print("The Mean squared error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 10.420
# The Mean squared error is 178.399
